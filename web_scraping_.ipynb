# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwathamudhan/Lok-Sabha-election-Data-Analysis/blob/main/web_scraping_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
#  ***Web Scraping***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install requests beautifulsoup4

# %%
from bs4 import BeautifulSoup
import requests

# %%
url= "https://results.eci.gov.in/PcResultGenJune2024/index.htm#"

page= requests.get(url)

soup= BeautifulSoup(page.text,'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <!-- Required meta tags -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=7" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="0" http-equiv="Expires"/>
# <meta content="300" http-equiv="refresh"/>
# <!-- Bootstrap CSS -->
# <link href="css/bootstrap.min.css" rel="stylesheet"/>
# <link href="css/custom.css" rel="stylesheet"/>
# <link href="css/responsive.css" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet"/>
# <link href="img/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>Election Commission of India</title>
# <style type="text/css">
# </style>
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="table">
#  <thead>
#  <tr>
#  <th style="text-align: left;">Party</th>
#  <th style="text-align:right">Won</th>
#  <th style="text-align:right">Leading</th>
#  <th style="text-align:right">Total</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="tr">
#  <td style="text-align:left">Bharatiya Janata Party - BJP</td>
#  <td style="text-align:right">
#  <a href="partywisewinresultState-369.htm">240</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">240</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Indian National Congress - INC</td>
#  <td style="text-align:right">
#  <a href="partywisewinresultState-742.htm">99</a>
#  </td>
#  <td style="text-align:right">
# ...

# %%
soup.find_all('table')
# Out:
# [<table class="table">
#  <thead>
#  <tr>
#  <th style="text-align: left;">Party</th>
#  <th style="text-align:right">Won</th>
#  <th style="text-align:right">Leading</th>
#  <th style="text-align:right">Total</th>
#  </tr>
#  </thead>
#  <tbody>
#  <tr class="tr">
#  <td style="text-align:left">Bharatiya Janata Party - BJP</td>
#  <td style="text-align:right">
#  <a href="partywisewinresultState-369.htm">240</a>
#  </td>
#  <td style="text-align:right">
#                                                                                          0
#                                                                                      </td>
#  <td style="text-align:right">240</td>
#  </tr>
#  <tr class="tr">
#  <td style="text-align:left">Indian National Congress - INC</td>
#  <td style="text-align:right">
#  <a href="partywisewinresultState-742.htm">99</a>
#  </td>
#  <td style="text-align:right">
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://results.eci.gov.in/PcResultGenJune2024/index.htm'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find('table', class_='table')
if table:
    print(table)
else:
    print("Table not found.")
# Out:
# <table class="table">
# <thead>
# <tr>
# <th style="text-align: left;">Party</th>
# <th style="text-align:right">Won</th>
# <th style="text-align:right">Leading</th>
# <th style="text-align:right">Total</th>
# </tr>
# </thead>
# <tbody>
# <tr class="tr">
# <td style="text-align:left">Bharatiya Janata Party - BJP</td>
# <td style="text-align:right">
# <a href="partywisewinresultState-369.htm">240</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">240</td>
# </tr>
# <tr class="tr">
# <td style="text-align:left">Indian National Congress - INC</td>
# <td style="text-align:right">
# <a href="partywisewinresultState-742.htm">99</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
# ...

# %%
titles=soup.find_all('th')
titles
# Out:
# [<th style="text-align: left;">Party</th>,
#  <th style="text-align:right">Won</th>,
#  <th style="text-align:right">Leading</th>,
#  <th style="text-align:right">Total</th>,
#  <th>Total</th>,
#  <th style="text-align:right">543</th>,
#  <th style="text-align:right">0</th>,
#  <th style="text-align:right">543</th>]

# %%
table_titles=[title.text for title in titles]
print(table_titles)
# Out:
# ['Party', 'Won', 'Leading', 'Total', 'Total', '543', '0', '543']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=table_titles)

df
# Out:
# Empty DataFrame
# Columns: [Party, Won, Leading, Total, Total, 543, 0, 543]
# Index: []

# %%
print(df.shape)
# Out:
# (0, 8)

# %%
df.drop(df.columns[[5,6,7]], axis=1, inplace=True)
duplicate_columns = df.columns[df.columns.duplicated()]
df = df.loc[:, ~df.columns.duplicated()]

# %%
table.find_all('tr') [1]
# Out:
# <tr class="tr">
# <td style="text-align:left">Bharatiya Janata Party - BJP</td>
# <td style="text-align:right">
# <a href="partywisewinresultState-369.htm">240</a>
# </td>
# <td style="text-align:right">
#                                                                                         0
#                                                                                     </td>
# <td style="text-align:right">240</td>
# </tr>

# %%
for row in column_data[1:]:
  row_data=row.find_all('td')
  individual_row_data=[data.text.strip() for data in row_data]

  if len(individual_row_data) == len(df.columns):
      length=len(df)
      df.loc[length]= individual_row_data
  else:
      print("Skipping row due to column mismatch. Row data:", individual_row_data)
# Out:
# Skipping row due to column mismatch. Row data: []
# <ipython-input-274-5d732562c94f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[length]= individual_row_data
# <ipython-input-274-5d732562c94f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[length]= individual_row_data
# <ipython-input-274-5d732562c94f>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[length]= individual_row_data
# ...

# %%
df
# Out:
#                                               Party  Won Leading Total
# 0                      Bharatiya Janata Party - BJP  240       0   240
# 1                    Indian National Congress - INC   99       0    99
# 2                              Samajwadi Party - SP   37       0    37
# 3               All India Trinamool Congress - AITC   29       0    29
# 4                   Dravida Munnetra Kazhagam - DMK   22       0    22
# ..                                              ...  ...     ...   ...
# 331          Aazad Samaj Party (Kanshi Ram) - ASPKR    1       0     1
# 332                      Apna Dal (Soneylal) - ADAL    1       0     1
# 333                              AJSU Party - AJSUP    1       0     1
# 334  All India Majlis-E-Ittehadul Muslimeen - AIMIM    1       0     1
# 335                               Independent - IND    7       0     7
#
# [336 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %% [markdown]
# ---

# %% [markdown]
# **Grapic representation**

# %%
from matplotlib import pyplot as plt
_df_2['index'].plot(kind='line', figsize=(8, 4), title='index')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ---

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  counted = (series['index']
                .value_counts()
              .reset_index(name='counts')
              .rename({'index': 'index'}, axis=1)
              .sort_values('index', ascending=True))
  xs = counted['index']
  ys = counted['counts']
  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_1.sort_values('index', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('count()')

# %% [markdown]
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.bar(df["Party"], df["Won_Leading_Combined"], color='orange')
plt.xlabel('Party')
plt.ylabel('Seats Won and Leading Combined')
plt.title('Total Seats Won and Leading Combined by Each Party')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ---
#
#
#
# ---

# %%
df.to_csv('table.csv')

# %%
file_path = r'C:\Users\Ashwath Amudhan C A\Desktop\webscraping\table.csv'
df.to_csv(file_path, index=False)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# #  key insight Lok Sabha election
#
#
#
# 1. Total number of Parties.
# 2. Number of parties with names starting with 'A'
# 3. Party with the most seats won
# 4. Total number of seats for each party
# 5.   Party with the most seats won and leading combined
# 6. Party with the lowest seats won
# 7. Average seats won per party
# 8. Total seats won by all parties
# 9.  Total seats leading by all parties
# 10.  Party with the highest average seats won per contest
# ---

# %% [markdown]
# **key insight No 1 :Total number of Parties.**
#
# ---

# %%
total_constituencies = df["Party"].nunique()
print("key insight No 1 : Total number of Parties in Lok Sabha election .")
print(" Total number of Parties:", total_constituencies)
# Out:
# key insight No 1 : Total number of Parties in Lok Sabha election .
#  Total number of Parties: 42

# %% [markdown]
# **key insight No 2: Number of parties with names starting with 'A'**
#
# ---

# %%
num_parties_starting_with_a = df[df["Party"].str.startswith("A")]["Party"].nunique()
print("Number of parties with names starting with 'A':", num_parties_starting_with_a)
print("Parties starting with 'A':")
for party in list(df[df["Party"].str.startswith("A")]["Party"].unique()):
    print(party)
# Out:
# Number of parties with names starting with 'A': 7
# Parties starting with 'A':
# All India Trinamool Congress - AITC
# Aam Aadmi Party - AAAP
# Asom Gana Parishad - AGP
# Aazad Samaj Party (Kanshi Ram) - ASPKR
# Apna Dal (Soneylal) - ADAL
# AJSU Party - AJSUP
# All India Majlis-E-Ittehadul Muslimeen - AIMIM

# %% [markdown]
# **key insight No 3: Party with the most seats won**
#
# ---

# %%
most_seats_party = df.loc[df["Won"].idxmax(), "Party"]
print("Party with the most seats won:", most_seats_party)
# Out:
# Party with the most seats won: Bharatiya Janata Party - BJP

# %% [markdown]
# **key insight No 4 :Total number of seats for each party**
#
# ---

# %%
df.loc[:, 'Total'] = pd.to_numeric(df['Total'], errors='coerce')
total_seats_each_party = df.groupby("Party")["Total"].sum()
print("Insight 15: Total number of seats for each party:\n", total_seats_each_party)
# Out:
# Insight 15: Total number of seats for each party:
#  Party
# AJSU Party - AJSUP                                                            8
# Aam Aadmi Party - AAAP                                                       24
# Aazad Samaj Party (Kanshi Ram) - ASPKR                                        8
# All India Majlis-E-Ittehadul Muslimeen - AIMIM                                8
# All India Trinamool Congress - AITC                                         232
# Apna Dal (Soneylal) - ADAL                                                    8
# Asom Gana Parishad - AGP                                                      8
# Bharat Adivasi Party - BHRTADVSIP                                             8
# Bharatiya Janata Party - BJP                                               1920
# Communist Party of India  (Marxist) - CPI(M)                                 32
# Communist Party of India  (Marxist-Leninist)  (Liberation) - CPI(ML)(L)      16
# ...

# %% [markdown]
# **key insight No 5: Party with the most seats won and leading combined**
#
# ---

# %%
df.loc[:, "Won"] = pd.to_numeric(df["Won"])
df.loc[:, "Leading"] = pd.to_numeric(df["Leading"])
df.loc[:, "Won_Leading_Combined"] = df["Won"] + df["Leading"]
most_seats_won_leading_combined_party = df.loc[df["Won_Leading_Combined"].idxmax(), "Party"]
print(" Party with the most seats won and leading combined:", most_seats_won_leading_combined_party)
# Out:
#  Party with the most seats won and leading combined: Bharatiya Janata Party - BJP

# %% [markdown]
# **key insight No 6 :Party with the lowest seats won**
#
# ---

# %%
lowest_seats_won_party = df.loc[df["Won"].idxmin(), "Party"]
print(" Party with the lowest seats won:", lowest_seats_won_party)
# Out:
#  Party with the lowest seats won: United People’s Party, Liberal - UPPL

# %% [markdown]
# **key insight No 7:Average seats won per party**
#
# ---

# %%
average_seats_won = df["Won"].mean()
print(" Average seats won per party:", average_seats_won)
# Out:
#  Average seats won per party: 12.928571428571429

# %% [markdown]
# **key insight No 8 : Total seats won by all parties**
#
# ---

# %%
total_seats_won = df["Won"].sum()
print(" Total seats won by all parties:", total_seats_won)
# Out:
#  Total seats won by all parties: 4344

# %% [markdown]
# **key insight No 9: Total seats leading by all parties**
#
# ---

# %%
total_seats_leading = df["Leading"].sum()
print(" Total seats leading by all parties:", total_seats_leading)
# Out:
# Insight 6: Total seats leading by all parties: 0

# %% [markdown]
# **key insight No 10 : Party with the highest average seats won per contest**
#
# ---

# %%
highest_average_won_party = df.groupby("Party")["Won"].mean().idxmax()
print(" Party with the highest average seats won per contest:", highest_average_won_party)
# Out:
# Insight 16: Party with the highest average seats won per contest: Bharatiya Janata Party - BJP

# %% [markdown]
# ---
#
#
#
# ---
